# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import ipywidgets as ipw

# %% [markdown]
# #  Predator Prey Example
# Parameters: [starting populations] , [alpha, beta, delta, gamma]
#
# Sample Wikipedia data: [1.1 ,0.4, 0.1, 0.4]
#
# Canadian Lynx-Hare data: [20, 30] , [1.6, 3.2, 1.92, 0.56]

# %%
start = [20, 2] #starting populations [hare, lynx]
t = np.linspace(0,90,num=1000)

#data from 
alpha = 1.1
beta = 0.4
delta = 0.1
gamma = 0.4

params = [alpha, beta, delta, gamma]

def sim(start, t, params):
    #prey population start
    x = start[0]
    #predator population start
    y = start[1]
    
    #parameter initialization
    alpha = params[0]
    beta = params[1]
    delta = params[2]
    gamma = params[3]
    
    dxdt = alpha * x - beta * x * y
    dydt = delta * x * y - gamma * y
    
    return ([dxdt, dydt])

y = odeint(sim, start, t, args=(params,))
f, ax1 = plt.subplots(1)
line1, = ax1.plot(t,y[:,0], color="b", label = "Hare population")
line2, = ax1.plot(t,y[:,1], color="r", label = "Lynx population")
ax1.set_ylabel("Populations")
ax1.set_xlabel("Time")
plt.legend()
plt.show()

# %% [markdown]
# # Predator Prey Live graph
# including user input

# %%
#user input 
alpha = 1.6
beta = 3.2
delta = 1.92
gamma = 0.56
y = odeint(sim, start, t, args=(params,))
f, ax1 = plt.subplots(1)
line1, = ax1.plot(t,y[:,0], color="b", label = "Hare population")
line2, = ax1.plot(t,y[:,1], color="r", label = "Lynx population")
ax1.set_ylabel("Populations")
ax1.set_xlabel("Time")
plt.legend()
plt.show()

# %% [markdown]
# # Mutualism
# $$ dN1 / dt = r1 * N1 - a11 * N21 + B12 * N1 * N2
# $$ dN2 / dt = r2 * N2 - a22 * N22 + B21 * N1 * N2
